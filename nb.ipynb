# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
x = np.random.rand(5,512,513,3)
plt.figure(figsize=(20,4))
plt.subplots_adjust(wspace=0, hspace=0)
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(x[i])
    plt.axis('off')
plt.show()
